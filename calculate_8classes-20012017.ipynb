# %% [markdown]
# # Fit 8 Class GMM and Calculate Average Profiles
#
# This notebook will fit 8 class GMMs to UK-ESM historical Southern Ocean data 2001-2018, following Jones et al. 2019 (https://doi.org/10.1029/2018JC014629). These files are required to reproduce Figures YY from *Heuristic Methods for Determining the Number of Classes in Unsupervised Classification of Climate Models*, E. Boland et al. 2022 (doi to follow). This requires cluster_utils.py and input datafiles via the googleapi CMIP6 store (see cluster_utils.py for more info)
#
# Outputs stored in model/\[ensemble\]/\[nclasses\]/gmm.obj and data/\[ensemble\]/\[nclasses\]/avg.obj
#
# Please attribute any plots or code from this notebook using the DOI from Zenodo: to come
#
# Updated Nov 2022
# E Atkinson & E Boland [emmomp@bas.ac.uk](email:emmomp@bas.ac.uk)

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:46794")
client
# Out:
# <Client: 'tcp://127.0.0.1:46794' processes=1 threads=1, memory=8.00 GiB>

# %%
from dask_gateway import Gateway
gateway = Gateway()
from dask.distributed import Client

'''properly shutdown any previous clusters'''
clusters=gateway.list_clusters()
if clusters != []:
    print(f'found {len(clusters)} clusters')
    for cluster in clusters:
        cluster = gateway.connect(cluster.name)
        client=Client(cluster)
        client.close()
        cluster.shutdown()

# %%
client.close()

# %%
import numpy as np
import xarray as xr

import os
import pickle

import cluster_utils as flt

# %% [markdown]
# ### User options
# Leave as is to recreate the paper

# %%
# Number of classes 
model='model_20012017'
n_classes = 8
#Time range
tslice=slice('2001-01', '2017-12') 
#Depth range
levSel=slice(5, 2000)
ids = ['r1i1p1f2', 'r2i1p1f2', 'r3i1p1f2', 'r4i1p1f2', 'r5i1p1f3', 'r6i1p1f3', 'r7i1p1f3', 'r8i1p1f2', 'r9i1p1f2', 'r10i1p1f2'] 
npca=3 #number of PCA components
ntrain=7000 #number of profiles per month to use in training dataset

# %% [markdown]
# Uncomment the following two lines if you need to generate mask.npy:

# %%
#data = flt.retrieve_profiles(timeRange = slice('1995-01', '1995-02'))
#np.save('data/mask', data['n'])
mask = np.load('data/mask.npy', allow_pickle=True)

# %% [markdown]
# ### Train models and generate average profiles for chosen ensemble members and classes

# %%
avg_profiles = {}
for m_id in ids:
    
    #Check if data already exists
 
    path_n = '{}/{}/{}'.format(model,m_id, n_classes)
    if os.path.isfile('{}/avg_prof.obj'.format(path_n)):
        print('Found classification for {}, skipping'.format(m_id))
        continue
    else:
        
        print('Starting {}'.format(m_id))
        options = {'memberId' : m_id}
        path_id = '{}/{}'.format(model,m_id)
        # Check if pca & model already created
        if os.path.isfile('{}/pca.obj'.format(path_id)) and os.path.isfile('{}/gmm.obj'.format(path_n)):
            with open('{}/pca.obj'.format(path_id),'rb') as file:
                pca=pickle.load(file)
            with open('{}/gmm.obj'.format(path_n), 'rb') as file:
                gmm = pickle.load(file)            
        else:        #Generate training set and PCA model
            print('No model found, generating training set')
            [data_train,pca] = flt.generate_trainingset(timeRange = tslice, mask=mask, options=options,n_components=npca,N=ntrain,levSel=levSel)
            if not os.path.exists(path_id):
                os.makedirs(path_id)
            with open('{}/pca.obj'.format(path_id), 'wb') as file:
                pickle.dump(pca, file)
            if not os.path.exists(path_n):
                os.makedirs(path_n)    
            # Generate GMM model generated from training set
            print('Training GMM')
            gmm = flt.train_gmm(data_train, n_classes)
            with open('{}/gmm.obj'.format(path_n), 'wb') as file:
                pickle.dump(gmm, file)
            
        print('Loading full dataset')
        #Load full Southern Ocean data to fit
        data = flt.retrieve_profiles(timeRange=tslice,mask=mask,options=options,levSel=levSel)
        data = data.chunk({'time': data.sizes['time'], 'n': 1024})
        # Normalise the samples
        data_norm = flt.normalise_data(data, ('n', 'time')) 
        # Transform to PCA space
        data_trans = flt.pca_transform(data_norm, pca)
        print('Classifying full dataset into {} classes'.format(n_classes))
        # Classify full dataset
        data_classes = flt.gmm_classify(data_trans, gmm)
        print('Classification complete, writing to file'.format(n_classes))
        flt.write_tonc(data_classes.reset_index('n'),n_classes,m_id,'class',path_n)
        if os.path.isfile('{}/avg_prof.obj'.format(path_n)):
            print('Average profiles found')
            continue
        else:
            # Calculate average profiles for each class
            avg_prof = flt.avg_profiles(data, data_classes, n_classes)
            print('Average profiles calculated, writing to file'.format(n_classes))
            with open('{}/avg_prof.obj'.format(path_n), 'wb') as file:
                pickle.dump(avg_prof, file)      
        print('Done with {} classes'.format(n_classes))      
    
print('Done!')
# Out:
# Found classification for r1i1p1f2, skipping
# Found classification for r2i1p1f2, skipping
# Found classification for r3i1p1f2, skipping
# Starting r4i1p1f2
# Loading full dataset
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#      36 print('Loading full dataset')
#      37 #Load full Southern Ocean data to fit
# ---> 38 data = flt.retrieve_profiles(timeRange=tslice,mask=mask,options=options,levSel=levSel)
#      39 data = data.chunk({'time': data.sizes['time'], 'n': 1024})
#      40 # Normalise the samples
#
# File ~/OceanClustering_paper/cluster_utils.py:67, in retrieve_profiles(timeRange, levSel, maxLat, mask, options)
#      61 df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
#      62 dfFilt = df[df.variable_id.eq(options['dataVariableId'])
#      63 & df.source_id.eq(options['dataSourceId'])
#      64 & df.table_id.eq(options['tableId'])
#      65 & df.experiment_id.eq(options['experimentId'])
#      66 & df.member_id.eq(options['memberId'])]
# ---> 67 filesRaw = [xr.open_zarr(fsspec.get_mapper(item), consolidated=True) for item in dfFilt.zstore.values]
#      70 for (i, v) in enumerate(filesRaw): #Formatting dates into np.datetime64 format
#      71     startDateIterate = np.datetime64(v['time'].values[0],'M')
#
# File ~/OceanClustering_paper/cluster_utils.py:67, in <listcomp>(.0)
#      61 df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv')
#      62 dfFilt = df[df.variable_id.eq(options['dataVariableId'])
#      63 & df.source_id.eq(options['dataSourceId'])
#      64 & df.table_id.eq(options['tableId'])
#      65 & df.experiment_id.eq(options['experimentId'])
#      66 & df.member_id.eq(options['memberId'])]
# ---> 67 filesRaw = [xr.open_zarr(fsspec.get_mapper(item), consolidated=True) for item in dfFilt.zstore.values]
#      70 for (i, v) in enumerate(filesRaw): #Formatting dates into np.datetime64 format
#      71     startDateIterate = np.datetime64(v['time'].values[0],'M')
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/fsspec/mapping.py:230, in get_mapper(url, check, create, missing_exceptions, alternate_root, **kwargs)
#     199 """Create key-value interface for given URL and options
#     200
#     201 The URL will be of the form "protocol://location" and point to the root
#    (...)
#     227 ``FSMap`` instance, the dict-like key-value store.
#     228 """
#     229 # Removing protocol here - could defer to each open() on the backend
# --> 230 fs, urlpath = url_to_fs(url, **kwargs)
#     231 root = alternate_root if alternate_root is not None else urlpath
#     232 return FSMap(root, fs, check, create, missing_exceptions=missing_exceptions)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/fsspec/core.py:412, in url_to_fs(url, **kwargs)
#     410     options = cls._get_kwargs_from_urls(url)
#     411     update_storage_options(options, kwargs)
# --> 412     fs = cls(**options)
#     413     urlpath = fs._strip_protocol(url)
#     414 return fs, urlpath
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/fsspec/spec.py:76, in _Cached.__call__(cls, *args, **kwargs)
#      74     return cls._cache[token]
#      75 else:
# ---> 76     obj = super().__call__(*args, **kwargs)
#      77     # Setting _fs_token here causes some static linters to complain.
#      78     obj._fs_token_ = token
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/gcsfs/core.py:280, in GCSFileSystem.__init__(self, project, access, token, block_size, consistency, cache_timeout, secure_serialize, check_connection, requests_timeout, requester_pays, asynchronous, session_kwargs, loop, timeout, endpoint_url, default_location, **kwargs)
#     274 if check_connection:
#     275     warnings.warn(
#     276         "The `check_connection` argument is deprecated and will be removed in a future release.",
#     277         DeprecationWarning,
#     278     )
# --> 280 self.credentials = GoogleCredentials(project, access, token)
#     282 if not self.asynchronous:
#     283     self._session = sync(
#     284         self.loop, get_client, timeout=self.timeout, **self.session_kwargs
#     285     )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/gcsfs/credentials.py:51, in GoogleCredentials.__init__(self, project, access, token, check_credentials)
#      49 self.lock = threading.Lock()
#      50 self.token = token
# ---> 51 self.connect(method=token)
#      53 if check_credentials:
#      54     warnings.warn(
#      55         "The `check_credentials` argument is deprecated and will be removed in a future release.",
#      56         DeprecationWarning,
#      57     )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/gcsfs/credentials.py:220, in GoogleCredentials.connect(self, method)
#     218 for meth in ["google_default", "cache", "cloud", "anon"]:
#     219     try:
# --> 220         self.connect(method=meth)
#     221         logger.debug("Connected with method %s", meth)
#     222         break
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/gcsfs/credentials.py:234, in GoogleCredentials.connect(self, method)
#     232         raise RuntimeError("All connection methods have failed!")
#     233 else:
# --> 234     self.__getattribute__("_connect_" + method)()
#     235     self.method = method
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/gcsfs/credentials.py:78, in GoogleCredentials._connect_google_default(self)
#      77 def _connect_google_default(self):
# ---> 78     credentials, project = gauth.default(scopes=[self.scope])
#      79     msg = textwrap.dedent(
#      80         """\
#      81     User-provided project '{}' does not match the google default project '{}'. Either
#    (...)
#      86     """
#      87     )
#      88     if self.project and self.project != project:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/google/auth/_default.py:583, in default(scopes, request, quota_project_id, default_scopes)
#     571 checkers = (
#     572     # Avoid passing scopes here to prevent passing scopes to user credentials.
#     573     # with_scopes_if_required() below will ensure scopes/default scopes are
#    (...)
#     579     lambda: _get_gce_credentials(request),
#     580 )
#     582 for checker in checkers:
# --> 583     credentials, project_id = checker()
#     584     if credentials is not None:
#     585         credentials = with_scopes_if_required(
#     586             credentials, scopes, default_scopes=default_scopes
#     587         )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/google/auth/_default.py:579, in default.<locals>.<lambda>()
#     565 from google.auth.credentials import CredentialsWithQuotaProject
#     567 explicit_project_id = os.environ.get(
#     568     environment_vars.PROJECT, os.environ.get(environment_vars.LEGACY_PROJECT)
#     569 )
#     571 checkers = (
#     572     # Avoid passing scopes here to prevent passing scopes to user credentials.
#     573     # with_scopes_if_required() below will ensure scopes/default scopes are
#     574     # safely set on the returned credentials since requires_scopes will
#     575     # guard against setting scopes on user credentials.
#     576     lambda: _get_explicit_environ_credentials(quota_project_id=quota_project_id),
#     577     lambda: _get_gcloud_sdk_credentials(quota_project_id=quota_project_id),
#     578     _get_gae_credentials,
# --> 579     lambda: _get_gce_credentials(request),
#     580 )
#     582 for checker in checkers:
#     583     credentials, project_id = checker()
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/google/auth/_default.py:281, in _get_gce_credentials(request)
#     278 if request is None:
#     279     request = google.auth.transport._http_client.Request()
# --> 281 if _metadata.ping(request=request):
#     282     # Get the project ID.
#     283     try:
#     284         project_id = _metadata.get_project_id(request=request)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/google/auth/compute_engine/_metadata.py:85, in ping(request, timeout, retry_count)
#      83 while retries < retry_count:
#      84     try:
# ---> 85         response = request(
#      86             url=_METADATA_IP_ROOT,
#      87             method="GET",
#      88             headers=_METADATA_HEADERS,
#      89             timeout=timeout,
#      90         )
#      92         metadata_flavor = response.headers.get(_METADATA_FLAVOR_HEADER)
#      93         return (
#      94             response.status == http_client.OK
#      95             and metadata_flavor == _METADATA_FLAVOR_VALUE
#      96         )
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/google/auth/transport/_http_client.py:106, in Request.__call__(self, url, method, body, headers, timeout, **kwargs)
#     103 try:
#     104     _LOGGER.debug("Making request: %s %s", method, url)
# --> 106     connection.request(method, path, body=body, headers=headers, **kwargs)
#     107     response = connection.getresponse()
#     108     return Response(response)
#
# File /srv/conda/envs/notebook/lib/python3.9/http/client.py:1285, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1282 def request(self, method, url, body=None, headers={}, *,
#    1283             encode_chunked=False):
#    1284     """Send a complete request to the server."""
# -> 1285     self._send_request(method, url, body, headers, encode_chunked)
#
# File /srv/conda/envs/notebook/lib/python3.9/http/client.py:1331, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1327 if isinstance(body, str):
#    1328     # RFC 2616 Section 3.7.1 says that text default has a
#    1329     # default charset of iso-8859-1.
#    1330     body = _encode(body, 'body')
# -> 1331 self.endheaders(body, encode_chunked=encode_chunked)
#
# File /srv/conda/envs/notebook/lib/python3.9/http/client.py:1280, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1278 else:
#    1279     raise CannotSendHeader()
# -> 1280 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /srv/conda/envs/notebook/lib/python3.9/http/client.py:1040, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1038 msg = b"\r\n".join(self._buffer)
#    1039 del self._buffer[:]
# -> 1040 self.send(msg)
#    1042 if message_body is not None:
#    1043
#    1044     # create a consistent interface to message_body
#    1045     if hasattr(message_body, 'read'):
#    1046         # Let file-like take precedence over byte-like.  This
#    1047         # is needed to allow the current position of mmap'ed
#    1048         # files to be taken into account.
#
# File /srv/conda/envs/notebook/lib/python3.9/http/client.py:980, in HTTPConnection.send(self, data)
#     978 if self.sock is None:
#     979     if self.auto_open:
# --> 980         self.connect()
#     981     else:
#     982         raise NotConnected()
#
# File /srv/conda/envs/notebook/lib/python3.9/http/client.py:946, in HTTPConnection.connect(self)
#     944 def connect(self):
#     945     """Connect to the host and port specified in __init__."""
# --> 946     self.sock = self._create_connection(
#     947         (self.host,self.port), self.timeout, self.source_address)
#     948     # Might fail in OSs that don't implement TCP_NODELAY
#     949     try:
#
# File /srv/conda/envs/notebook/lib/python3.9/socket.py:832, in create_connection(address, timeout, source_address)
#     830 if source_address:
#     831     sock.bind(source_address)
# --> 832 sock.connect(sa)
#     833 # Break explicitly a reference cycle
#     834 err = None
#
# KeyboardInterrupt:
